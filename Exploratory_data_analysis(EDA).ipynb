# %% [markdown]
# # EDA
# Exploratory Data Analysis (EDA) is an approach to analyze the data using visual techniques. It is used to discover trends(fashion,technology), patterns, or to check assumptions with the help of statistical summary and graphical representations
#
# The main purpose of EDA is to help look at data before making any assumptions. It can help identify obvious errors, as well as better understand patterns within the data, detect outliers or anomalous events, find interesting relations among the variables.
#
# Importance of using EDA for analyzing data sets is:
#
# Helps identify errors in data sets.
# Gives a better understanding of the data set.
# Helps detect outliers or anomalous (abnormal) events.
# Helps understand data set variables and the relationship among them.

# %% [markdown]
# Univariate data analysis: Uni means one and variate means variable, so in univariate analysis, there is only one dependable variable. The objective of univariate analysis is to derive the data, define and summarize it, and analyze the pattern present in it. In a dataset, it explores each variable separately. It is possible for two kinds of variables- Categorical and Numerical.

# %% [markdown]
# Some patterns that can be easily identified with univariate analysis are Central Tendency (mean, mode and median), Dispersion (range, variance), Quartiles (interquartile range), and Standard deviation.

# %% [markdown]
# Types of Descriptive Statistics
# Baseline Help Center  Using Baseline  Analysis & Reporting
# Descriptive statistics allow you to characterize your data based on its properties. There are four major types of descriptive statistics:
#
# 1. Measures of Frequency:
#     * Count, Percent, Frequency
#     * Shows how often something occurs
#     * Use this when you want to show how often a response is given
#
# 2. Measures of Central Tendency
#     * Mean, Median, and Mode
#     * Locates the distribution by various points
#     * Use this when you want to show how an average or most commonly indicated response
#
# 3. Measures of Dispersion or Variation
#     * Range, Variance, Standard Deviation
#     * Identifies the spread of scores by stating intervals
#     * Range = High/Low points
#     * Variance or Standard Deviation = difference between observed score and mean
#     * Use this when you want to show how "spread out" the data are. It is helpful to know when your data are so spread out that it affects the mean
# 4.
# Measures of Position
#     * Percentile Ranks, Quartile Ranks
#     * Describes how scores fall in relation to one another. Relies on standardized scores
#     * Use this when you need to compare scores to a normalized score (e.g., a national norm)

# %% [markdown]
# https://towardsdatascience.com/8-seaborn-plots-for-univariate-exploratory-data-analysis-eda-in-python-9d280b6fe67f

# %% [markdown]
# https://analyse-it.com/docs/user-guide/distribution/continuous/univariate-descriptive-statistics

# %% [markdown]
# # univariate Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
titanic = sns.load_dataset('titanic')
flight = sns.load_dataset('flights')
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')

# %% [markdown]
# # Univariate comparison plots

# %%
# seaborn.countplot() method is used to Show the counts of observations in 
# each categorical bin using bars.
sns.countplot(data=titanic , x=titanic['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=titanic , x=titanic['pclass'])
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
#embarked - begin - start - commence
sns.countplot(data=titanic , x=titanic['embarked'])
# Out:
# <AxesSubplot:xlabel='embarked', ylabel='count'>

# %%
sns.countplot(data=titanic , x=titanic['survived'])
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
titanic['sex'].value_counts().plot(kind = 'pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
titanic['survived'].value_counts().plot(kind = 'pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='survived'>

# %%
titanic['embarked'].value_counts().plot(kind = 'pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='embarked'>

# %% [markdown]
# # Univariate Distribution Plots.

# %%
# A distplot plots a univariate distribution of observations. 
# The distplot() function combines the matplotlib hist function with the 
# seaborn kdeplot() and rugplot() functions.
# https://pythonbasics.org/seaborn-distplot/
sns.displot(titanic['age'], kind='hist')

# %%
sns.histplot(titanic['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.displot(titanic['age'], kind='kde')

# %%
sns.displot(titanic['age'], kind='hist', kde=True)

# %%
sns.displot(titanic['age'], kind='ecdf')

# %%
# A box plot (or box-and-whisker plot) shows the distribution of quantitative 
# data in a way that facilitates comparisons between variables or across 
# levels of a categorical variable.
sns.boxplot(titanic['age'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# # Univariate composition plots

# %% [markdown]
# # Multivariate analysis

# %% [markdown]
# # Covariance and Correlation
#
# Covariance and Correlation are very helpful in understanding the relationship between two continuous variables.
#
#
# # Covariance:
# Covariance tells whether both variables vary in the same direction (positive covariance) or in the opposite direction (negative covariance). There is no meaning of covariance numerical value only sign is useful.
#
# In the study of covariance only sign matters. A positive value shows that both variables vary in the same direction and negative value shows that they vary in the opposite direction.
#
# Covariance between two variables x and y can be calculated as follows:
#
#
#
# Where:
#
#     *x̄ is the sample mean of x
#     *ȳ is sample mean of y
#     *x_i and y_i are the values of x and y for ith record in the sample.
#     *n is the no of records in the sample
#
# # Correlation:
#
# Correlation explains the change in one variable leads how much proportion change in the second variable. Correlation varies between -1 to +1. If the correlation value is 0 then it means there is no Linear Relationship between variables however other functional relationship may exist.
#
# Correlation tells us both the strength and the direction of this relationship. Correlation is best used for multiple variables that express a linear relationship with one another. When we assume a correlation between two variables, we are essentially deducing (Predict/ನಿರ್ಣಯಿಸಿ) that a change in one variable impacts a change in another variable. Correlation helps us to determine whether or not, and how strongly, changes in various variables relate to each other.
#
# Correlation between x and y can be calculated as follows:
#
#
# Where:
#
#     *S_xy is the covariance between x and y.
#     *S_x and S_y are the standard deviations of x and y respectively.
#     *r_xy is the correlation coefficient.
#
# The correlation coefficient is a dimensionless quantity. Hence if we change the unit of x and y then also the coefficient value will remain the same.

# %% [markdown]
# # Multivariate distribution plot

# %%
# Density - compactness,tightness,ಸಾಂದ್ರತೆ
sns.distplot(titanic['age'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(titanic[titanic['survived']==0]['age'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(titanic[titanic['survived']==1]['age'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(titanic[titanic['survived']==0]['age'], hist=False)
sns.distplot(titanic[titanic['survived']==1]['age'], hist=False)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(titanic[titanic['sex']=='male']['age'], hist=False)
sns.distplot(titanic[titanic['sex']=='female']['age'], hist=False)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Multivariate comparison plot

# %%
# This function provides access to several axes-level functions that show 
# the relationship between a numerical and one or more categorical variables 
# using one of several visual representations.
sns.catplot(data=tips, x="day", y="total_bill")

# %%
sns.pairplot(tips)

# %%
sns.countplot(titanic['sex'], hue=titanic['survived'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.barplot(titanic['pclass'],titanic['age'] ,hue=titanic['sex'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(titanic['sex'],titanic['age'], hue=titanic['survived'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# # Multivariate relationship plot

# %%
sns.scatterplot(tips['total_bill'],tips['tip'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(tip['total_bill'],tips['tip'], hue=tips['sex'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(tip['total_bill'],tips['tip'], hue=tips['sex'], style=tips['smoker'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(tip['total_bill'],tips['tip'], hue=tips['sex'], style=tips['smoker'], size=tips['size'], legend='brief')
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=flight, x=flight['year'],y=flight['passengers'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
(titanic.groupby('pclass').mean()['survived']*100).plot(kind='bar')
# df = titanic.groupby('pclass').mean()['survived']*100
# df.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
(titanic.groupby('sex').mean()['survived']*100).plot(kind='bar')
# df = titanic.groupby('pclass').mean()['survived']*100
# df.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
(titanic.groupby('embarked').mean()['survived']*100).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='embarked'>

# %% [markdown]
# # Multivariate composition plot

# %%
b = pd.crosstab(titanic['pclass'], titanic['survived'])

# %%
sns.heatmap(b)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='pclass'>
